# %% [markdown]
# HelpDesk system wiring notes: backend Flask with /tickets (POST+GET) and /metrics connected to React frontend screens for submit, operator, conversation, and dashboard.

# %% [markdown]
# TODO: hook conversation chat list to backend ticket fields (last_text, answer, summary).

# %% [markdown]
# Backend: extend ticket_record with last_text, answer, auto_resolve, need_human. Frontend: extend TicketRow and replace static conversation bubbles with selectedTicket-driven content.
